# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
import sys
from rdflib import Graph,URIRef
import pandas as pd
pd.set_option("display.width",100)
pd.set_option("display.max_colwidth",80)

# %% [markdown]
# # Introduction
# * How to query the web of data
# * SPARQL / RestAPIs
# * Presentation uses:
#     * Python 3.9
#     * Jupyter notebook
#     * RDFlib
#     * requests
#     * pyleaflet

# %% [markdown]
# # SPARQL
# * Query language for the semantic web
# * since 2008 W3C recommendation
# * since 2013 SPARQL 1.1 W3C recommendation

# %% [markdown]
# ![title](img/sparql_anatomy.png)

# %% [markdown]
# # SPARQL
# * Several
#     * SELECT: select values and return them (we will only use that)
#     * CONSTRUCT: create a new Graph
#     * ASK: Boolean (True/False)
#     * DESCRIBE: Describe a resource

# %% [markdown]
# ![title](img/4_types_sparql.png)

# %% [markdown]
# ### Representational State Transfer (Rest)
# * set of software architectual constraints to be used for web services
# * requests made to a resource's URI will elicit a response with a payload (in JSON, XML etc)
#     * response can e.g. be a confirmation that an operation on the resource has been done
#     * or a hyperlinked relation to another resource

# %% [markdown]
# ### most common HTTP methods
# * GET: Retrieve data
# * POST: Create new data
# * PUT: Update whole object
# * PATCH: Update part of the object
# * DELETE: Delete object

# %% [markdown]
# ### HTTP Header
# * used to define operating parameters
#     * Accept: Used to set the media type that is accepted by the request: "Accept: application/json"
#     * Accept-Charset: encoding that is accepted: "utf-8"
#     * Authorization: Authentication credentials: "Token TOKEN"

# %% [markdown]
# ### Some useful examples for Rest services in the DH
# * Lobid: https://lobid.org/
# * VIAF: https://platform.worldcat.org/api-explorer/apis
# * Peripleo (Pelagios): https://github.com/pelagios/peripleo/blob/master/README.md
# * ACDHs enrich service: https://enrich.acdh.oeaw.ac.at/
# * ACDHs APIS ÖBL instance: https://apis.acdh.oeaw.ac.at/apis/api
# * ACDHs HistoGIS: https://histogis.acdh.oeaw.ac.at/
# * ACDHs spacyapp: https://spacyapp.acdh-dev.oeaw.ac.at/query/nlppipeline/

# %% [markdown]
# # SPARQL query against local RDF

# %%
g=Graph()

# %%
g.parse('https://d-nb.info/gnd/118566512/about/lds.rdf')
# Out:
# <Graph identifier=N5cd0b498c9af417bbfc1492da9097886 (<class 'rdflib.graph.Graph'>)>

# %%
properties = g.query("""
   SELECT ?s ?p ?o 
   WHERE {
      # ?s ?p ?o .
   }
""")
df_kreisky =  pd.DataFrame(properties)
df_kreisky
# Out:
#                                         0  \
# 0         https://d-nb.info/gnd/118566512
# 1         https://d-nb.info/gnd/118566512
# 2         https://d-nb.info/gnd/118566512
# 3         https://d-nb.info/gnd/118566512
# 4         https://d-nb.info/gnd/118566512
# 5       N7f171298a0fe4be295880145c4804e63
# 6         https://d-nb.info/gnd/118566512
# 7         https://d-nb.info/gnd/118566512
# 8         https://d-nb.info/gnd/118566512
# 9         https://d-nb.info/gnd/118566512
# 10        https://d-nb.info/gnd/118566512
# 11        https://d-nb.info/gnd/118566512
# 12        https://d-nb.info/gnd/118566512
# 13        https://d-nb.info/gnd/118566512
# 14        https://d-nb.info/gnd/118566512
# 15        https://d-nb.info/gnd/118566512
# 16        https://d-nb.info/gnd/118566512
# 17        https://d-nb.info/gnd/118566512
# 18        https://d-nb.info/gnd/118566512
# 19        https://d-nb.info/gnd/118566512
# 20        https://d-nb.info/gnd/118566512
# 21        https://d-nb.info/gnd/118566512
# 22        https://d-nb.info/gnd/118566512
# 23  https://d-nb.info/gnd/118566512/about
# 24        https://d-nb.info/gnd/118566512
# 25        https://d-nb.info/gnd/118566512
# 26        https://d-nb.info/gnd/118566512
# 27        https://d-nb.info/gnd/118566512
# 28        https://d-nb.info/gnd/118566512
# 29        https://d-nb.info/gnd/118566512
# 30      N7f171298a0fe4be295880145c4804e63
# 31  https://d-nb.info/gnd/118566512/about
#
#                                                                                  1  \
# 0                                             http://www.w3.org/2002/07/owl#sameAs
# 1                https://d-nb.info/standards/elementset/gnd#professionOrOccupation
# 2                                             http://www.w3.org/2002/07/owl#sameAs
# 3   https://d-nb.info/standards/elementset/gnd#biographicalOrHistoricalInformation
# 4                    https://d-nb.info/standards/elementset/gnd#oldAuthorityNumber
# 5                              https://d-nb.info/standards/elementset/gnd#forename
# 6                          https://d-nb.info/standards/elementset/gnd#placeOfBirth
# 7                                             http://www.w3.org/2002/07/owl#sameAs
# 8   https://d-nb.info/standards/elementset/gnd#biographicalOrHistoricalInformation
# 9                                             http://www.w3.org/2002/07/owl#sameAs
# 10                                                  http://xmlns.com/foaf/0.1/page
# 11                          https://d-nb.info/standards/elementset/gnd#affiliation
# 12                          https://d-nb.info/standards/elementset/gnd#dateOfBirth
# 13      https://d-nb.info/standards/elementset/gnd#preferredNameEntityForThePerson
# 14                   https://d-nb.info/standards/elementset/gnd#geographicAreaCode
# 15                          https://d-nb.info/standards/elementset/gnd#dateOfDeath
# 16                        https://d-nb.info/standards/elementset/gnd#gndIdentifier
# 17                                  http://www.w3.org/2007/05/powder-s#describedby
# 18                 https://d-nb.info/standards/elementset/gnd#familialRelationship
# 19                                 http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 20                   https://d-nb.info/standards/elementset/gnd#geographicAreaCode
# 21                   https://d-nb.info/standards/elementset/gnd#gndSubjectCategory
# 22                               https://d-nb.info/standards/elementset/gnd#gender
# 23                                               http://purl.org/dc/terms/modified
# 24                         https://d-nb.info/standards/elementset/gnd#placeOfDeath
# 25                                            http://www.w3.org/2002/07/owl#sameAs
# 26                                            http://www.w3.org/2002/07/owl#sameAs
# 27                         https://d-nb.info/standards/elementset/gnd#placeOfExile
# 28            https://d-nb.info/standards/elementset/gnd#preferredNameForThePerson
# 29                   https://d-nb.info/standards/elementset/gnd#oldAuthorityNumber
# 30                              https://d-nb.info/standards/elementset/gnd#surname
# 31                                                http://purl.org/dc/terms/license
#
#                                                                    2
# 0                          http://dbpedia.org/resource/Bruno_Kreisky
# 1                                    https://d-nb.info/gnd/4046517-2
# 2   http://www.filmportal.de/person/5B113A52F8F14A879694D08C56BCEE81
# 3                                             Politiker, Oesterreich
# 4                                                 (DE-588a)118566512
# 5                                                              Bruno
# 6                                    https://d-nb.info/gnd/4066009-6
# 7                                      http://viaf.org/viaf/31998484
# 8                                            Bundeskanzler 1970-1983
# 9                             http://id.loc.gov/rwo/agents/n50043948
# 10                       https://de.wikipedia.org/wiki/Bruno_Kreisky
# 11                                   https://d-nb.info/gnd/2029382-3
# 12                                                        1911-01-22
# 13                                 N7f171298a0fe4be295880145c4804e63
# 14  https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT
# 15                                                        1990-07-29
# 16                                                         118566512
# 17                             https://d-nb.info/gnd/118566512/about
# 18                                   https://d-nb.info/gnd/121036073
# 19   https://d-nb.info/standards/elementset/gnd#DifferentiatedPerson
# 20  https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-SE
# 21                https://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p
# 22                 https://d-nb.info/standards/vocab/gnd/gender#male
# 23                                               2019-07-10T17:25:44
# 24                                   https://d-nb.info/gnd/4066009-6
# 25                             http://isni.org/isni/0000000112608767
# 26                             http://www.wikidata.org/entity/Q44517
# 27                                   https://d-nb.info/gnd/4077258-5
# 28                                                    Kreisky, Bruno
# 29                                                (DE-588c)4032993-8
# 30                                                           Kreisky
# 31                 http://creativecommons.org/publicdomain/zero/1.0/

# %%
properties = g.query("""
   SELECT (COUNT(*) AS ?cnt) {
      # ?s ?p ?o .
   }
""")
df_kreisky =  pd.DataFrame(properties)
df_kreisky
# Out:
#     0
# 0  32

# %% [markdown]
# ### Example SPARQL request wikidata

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import requests

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
SELECT 
  # ?country ?population ?gnd ?capital
WHERE {
  # ?country wdt:P31 wd:Q261543.
  # ?country wdt:P1082 ?population .
  # ?country wdt:P227 ?gnd .
  # ?country wdt:P36 ?capital
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results
# Out:
# {'head': {'vars': ['country', 'population', 'gnd', 'capital']},
#  'results': {'bindings': [{'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q37985'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41753'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '561293'},
#     'gnd': {'type': 'literal', 'value': '4029175-3'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q38981'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1737'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '397139'},
#     'gnd': {'type': 'literal', 'value': '4063944-7'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41358'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q13298'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1246395'},
#     'gnd': {'type': 'literal', 'value': '4057092-7'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41967'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41329'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1490279'},
#     'gnd': {'type': 'literal', 'value': '4075560-5'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42497'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q82500'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1684287'},
#     'gnd': {'type': 'literal', 'value': '4075391-8'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43210'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q126321'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '294436'},
#     'gnd': {'type': 'literal', 'value': '4009114-4'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43325'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q34713'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '558410'},
#     'gnd': {'type': 'literal', 'value': '4051423-7'}}]}}

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['capital.value', 'country.value', 'gnd.value', 'population.value']]
# Out:
#                             capital.value                          country.value  gnd.value  \
# 0   http://www.wikidata.org/entity/Q41753  http://www.wikidata.org/entity/Q37985  4029175-3
# 1    http://www.wikidata.org/entity/Q1737  http://www.wikidata.org/entity/Q38981  4063944-7
# 2   http://www.wikidata.org/entity/Q13298  http://www.wikidata.org/entity/Q41358  4057092-7
# 3   http://www.wikidata.org/entity/Q41329  http://www.wikidata.org/entity/Q41967  4075560-5
# 4   http://www.wikidata.org/entity/Q82500  http://www.wikidata.org/entity/Q42497  4075391-8
# 5  http://www.wikidata.org/entity/Q126321  http://www.wikidata.org/entity/Q43210  4009114-4
# 6   http://www.wikidata.org/entity/Q34713  http://www.wikidata.org/entity/Q43325  4051423-7
#
#   population.value
# 0           561293
# 1           397139
# 2          1246395
# 3          1490279
# 4          1684287
# 5           294436
# 6           558410

# %%
sparql.setQuery("""
SELECT 
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel
WHERE {
  # ?country wdt:P31 wd:Q261543.
  # ?country wdt:P1082 ?population .
  # ?country wdt:P227 ?gnd .
  # ?country wdt:P36 ?capital
SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value']]
# Out:
#   capitalLabel.value countryLabel.value  gnd.value population.value
# 0         Klagenfurt          Carinthia  4029175-3           561293
# 1            Bregenz         Vorarlberg  4063944-7           397139
# 2               Graz             Styria  4057092-7          1246395
# 3               Linz      Upper Austria  4075560-5          1490279
# 4         St. Pölten      Lower Austria  4075391-8          1684287
# 5         Eisenstadt         Burgenland  4009114-4           294436
# 6           Salzburg           Salzburg  4051423-7           558410

# %% [markdown]
# # Combining graph patterns in SPARQL
# * Conjunction:  A . B >> Join results of solving A and B
# * Left join: A OPTIONAL { B } >> keep all the results from A whether or not there are results from B
# * Disjunction: { A } UNION { B } >> keep results from solving A and solving B
# * Negation: A MINUS { B } >> Keep only those results from A that are not compatible with B

# %%
sparql.setQuery("""
SELECT 
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital }
SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value']]
# Out:
#   capitalLabel.value countryLabel.value  gnd.value population.value
# 0                NaN             Vienna  4066009-6          1840573
# 1         Klagenfurt          Carinthia  4029175-3           560300
# 2            Bregenz         Vorarlberg  4063944-7           388711
# 3               Graz             Styria  4057092-7          1231865
# 4               Linz      Upper Austria  4075560-5          1453733
# 5         St. Pölten      Lower Austria  4075391-8          1653419
# 6          Innsbruck              Tyrol        NaN           739002
# 7         Eisenstadt         Burgenland  4009114-4           291023
# 8           Salzburg           Salzburg  4051423-7           545742

# %%
sparql.setQuery("""
SELECT DISTINCT
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel ?populationCapital ?populationShareCapital
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital .
          # ?capital wdt:P1082 ?populationCapital
  }
  FILTER(str(?capitalLabel) = 'Graz')
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sparql.setQuery("""
SELECT DISTINCT
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel ?populationCapital ?populationShareCapital
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital .
          # ?capital wdt:P1082 ?populationCapital;
                    rdfs:label ?labelcapital
  }
  FILTER(str(?labelcapital) = 'Graz')
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value', 'populationCapital.value']]
# Out:
#   capitalLabel.value countryLabel.value  gnd.value population.value populationCapital.value
# 0               Graz             Styria  4057092-7          1231865                  289440

# %% [markdown]
# ![title](img/filters_sparql.png)

# %%
sparql.setQuery("""
SELECT DISTINCT
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel ?populationCapital ?populationShareCapital
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital .
          # ?capital wdt:P1082 ?populationCapital
  }
  BIND(?populationCapital / ?population AS ?populationShareCapital)
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value', 'populationShareCapital.value']]
# Out:
#    capitalLabel.value countryLabel.value  gnd.value population.value populationShareCapital.value
# 0                Graz             Styria  4057092-7          1231865       0.23496081145255364833
# 1          Klagenfurt          Carinthia  4029175-3           560300       0.17913439228984472604
# 2             Bregenz         Vorarlberg  4063944-7           388711       0.07382605586155267024
# 3                 NaN             Vienna  4066009-6          1840573                          NaN
# 4                Linz      Upper Austria  4075560-5          1453733       0.14091033222744479213
# 5          St. Pölten      Lower Austria  4075391-8          1653419       0.03232392998991786111
# 6          Klagenfurt          Carinthia  4029175-3           560300       0.17903980010708548992
# 7           Innsbruck              Tyrol        NaN           739002       0.17712266001986462824
# 8            Salzburg           Salzburg  4051423-7           545742         0.282323881980862752
# 9          Eisenstadt         Burgenland  4009114-4           291023       0.04974177298701477203
# 10         Eisenstadt         Burgenland  4009114-4           291023       0.04893427667229050625

# %%
sparql.setQuery("""
SELECT DISTINCT
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel ?populationCapital ?lat_long
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P3529 ?medianIncome }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital .
          # ?capital wdt:P1082 ?populationCapital
  }
  OPTIONAL { ?country wdt:P625 ?lat_long }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['countryLabel.value', 'lat_long.value',]]
# Out:
#    countryLabel.value                    lat_long.value
# 0            Salzburg  Point(13.364166666 47.766944444)
# 1          Burgenland          Point(16.416666666 47.5)
# 2          Burgenland          Point(16.416666666 47.5)
# 3       Lower Austria         Point(15.75 48.333333333)
# 4           Carinthia  Point(13.818888888 46.761111111)
# 5           Carinthia  Point(13.818888888 46.761111111)
# 6       Upper Austria                  Point(14.0 48.2)
# 7              Styria         Point(15.166666666 47.25)
# 8               Tyrol          Point(11.4 47.266666666)
# 9          Vorarlberg   Point(9.893888888 47.243611111)
# 10             Vienna         Point(16.373064 48.20833)

# %%
import re
for idx, row in results_df.iterrows():
    print(row['lat_long.value'], type(row['lat_long.value']))
# Out:
# Point(13.364166666 47.766944444) <class 'str'>
# Point(16.416666666 47.5) <class 'str'>
# Point(16.416666666 47.5) <class 'str'>
# Point(15.75 48.333333333) <class 'str'>
# Point(13.818888888 46.761111111) <class 'str'>
# Point(13.818888888 46.761111111) <class 'str'>
# Point(14.0 48.2) <class 'str'>
# Point(15.166666666 47.25) <class 'str'>
# Point(11.4 47.266666666) <class 'str'>
# Point(9.893888888 47.243611111) <class 'str'>
# Point(16.373064 48.20833) <class 'str'>

# %%
for idx, row in results_df.iterrows():
    lat_long = re.match('Point\(([0-9\.]+)\s([0-9\.]+)\)', row['lat_long.value'])
    if lat_long:
        long = lat_long.group(1)
        lat = lat_long.group(2)
        print(lat, long)
        results_df.at[idx, 'lat'] = lat
        results_df.at[idx, 'long'] = long
# Out:
# 47.766944444 13.364166666
# 47.5 16.416666666
# 47.5 16.416666666
# 48.333333333 15.75
# 46.761111111 13.818888888
# 46.761111111 13.818888888
# 48.2 14.0
# 47.25 15.166666666
# 47.266666666 11.4
# 47.243611111 9.893888888
# 48.20833 16.373064

# %%
results_df[['countryLabel.value', 'lat_long.value', 'lat', 'long']]
# Out:
#    countryLabel.value                    lat_long.value           lat          long
# 0            Salzburg  Point(13.364166666 47.766944444)  47.766944444  13.364166666
# 1          Burgenland          Point(16.416666666 47.5)          47.5  16.416666666
# 2          Burgenland          Point(16.416666666 47.5)          47.5  16.416666666
# 3       Lower Austria         Point(15.75 48.333333333)  48.333333333         15.75
# 4           Carinthia  Point(13.818888888 46.761111111)  46.761111111  13.818888888
# 5           Carinthia  Point(13.818888888 46.761111111)  46.761111111  13.818888888
# 6       Upper Austria                  Point(14.0 48.2)          48.2          14.0
# 7              Styria         Point(15.166666666 47.25)         47.25  15.166666666
# 8               Tyrol          Point(11.4 47.266666666)  47.266666666          11.4
# 9          Vorarlberg   Point(9.893888888 47.243611111)  47.243611111   9.893888888
# 10             Vienna         Point(16.373064 48.20833)      48.20833     16.373064

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, Marker
watercolor = basemap_to_tiles(basemaps.Stamen.Watercolor)
center = (results_df.at[0, 'lat'], results_df.at[0, 'long'])
m = Map(layers=(watercolor, ), center=center, zoom=3)
marker = Marker(location=center, draggable=False)
m.add_layer(marker)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, Marker
watercolor = basemap_to_tiles(basemaps.Stamen.Watercolor)
center = (results_df.at[0, 'lat'], results_df.at[0, 'long'])
m = Map(layers=(watercolor, ), center=center, zoom=6)
marker = Marker(location=center, draggable=False)
m.add_layer(marker)
for idx, row in results_df.loc[1:,:].iterrows():
    center = (row['lat'], row['long'])
    marker = Marker(location=center, draggable=False)
    m.add_layer(marker)

# %%
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value', 'lat', 'long']]
# Out:
#    capitalLabel.value countryLabel.value  gnd.value population.value           lat          long
# 0            Salzburg           Salzburg  4051423-7           545742  47.766944444  13.364166666
# 1          Eisenstadt         Burgenland  4009114-4           291023          47.5  16.416666666
# 2          Eisenstadt         Burgenland  4009114-4           291023          47.5  16.416666666
# 3          St. Pölten      Lower Austria  4075391-8          1653419  48.333333333         15.75
# 4          Klagenfurt          Carinthia  4029175-3           560300  46.761111111  13.818888888
# 5          Klagenfurt          Carinthia  4029175-3           560300  46.761111111  13.818888888
# 6                Linz      Upper Austria  4075560-5          1453733          48.2          14.0
# 7                Graz             Styria  4057092-7          1231865         47.25  15.166666666
# 8           Innsbruck              Tyrol        NaN           739002  47.266666666          11.4
# 9             Bregenz         Vorarlberg  4063944-7           388711  47.243611111   9.893888888
# 10                NaN             Vienna  4066009-6          1840573      48.20833     16.373064

# %%
url = 'https://histogis.acdh-dev.oeaw.ac.at/api/where-was'
res_geo = []
for idx, row in results_df.iterrows():
    params = {'lat': row['lat'], 'lng': row['long'], 'when': '1870'}
    res = requests.get(url, params=params)
    df_geo = pd.io.json.json_normalize(res.json()['features'])
    df_geo.at[:,'wikidata'] = row['country.value']
    res_geo.append(df_geo)

# %%
res_geo[0][['@id', 'names', 'properties.adm_name', 'properties.start_date', 'properties.end_date']]
# Out:
#                                                                                @id  \
# 0  https://histogis.acdh-dev.oeaw.ac.at/shapes/permalink/28fbba0204589a8a0da575...
#
#                                     names     properties.adm_name properties.start_date  \
# 0  [{'toponym': 'Salzburg (Landbezirk)'}]  Bezirkshauptmannschaft            1867-02-28
#
#   properties.end_date
# 0          1896-07-30

# %%
url = res_geo[0].at[0, '@id']
HTML('<a href="{}">{}</a>'.format(url, url))
# Out:
# <a href="https://histogis.acdh-dev.oeaw.ac.at/shapes/permalink/28fbba0204589a8a0da575665005f6ce/">https://histogis.acdh-dev.oeaw.ac.at/shapes/permalink/28fbba0204589a8a0da575665005f6ce/</a>

# %%
url = res_geo[0].at[0, 'wikidata']
HTML('<a href="{}">{}</a>'.format(url, url))
# Out:
# <a href="http://www.wikidata.org/entity/Q43325">http://www.wikidata.org/entity/Q43325</a>

# %% [markdown]
# ### Example request to lobid

# %%
import requests

# %%
headers = {'accept': 'application/json'}
params = {'q': 'preferredName:Kreisky, Bruno', 'filter': 'type:Person'}
url = 'https://lobid.org/gnd/search'
res = requests.get(url, params=params, headers=headers)

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'@context': 'https://lobid.org/gnd/context.jsonld',
#  'id': 'https://lobid.org/gnd/search?q=preferredName%3AKreisky%2C+Bruno&filter=type%3APerson',
#  'totalItems': 3,
#  'member': [{'professionOrOccupation': [{'id': 'http://d-nb.info/gnd/4046517-2',
#      'label': 'Politiker'}],
#    'placeOfBirth': [{'id': 'http://d-nb.info/gnd/4066009-6', 'label': 'Wien'}],
#    'gender': [{'id': 'http://d-nb.info/standards/vocab/gnd/gender#male',
#      'label': 'Männlich'}],
#    'dateOfDeath': ['1990-07-29'],
#    'dateOfBirth': ['1911-01-22'],
#    'placeOfDeath': [{'id': 'http://d-nb.info/gnd/4066009-6', 'label': 'Wien'}],
#    'familialRelationship': [{'id': 'http://d-nb.info/gnd/121036073',
#      'label': 'Kreisky, Eva'}],
#    'type': ['Person', 'DifferentiatedPerson', 'AuthorityResource'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'gndSubjectCategory': [{'id': 'http://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p',
#      'label': 'Personen der Geschichte (Politiker und historische Persönlichkeiten)'}],
#    'oldAuthorityNumber': ['(DE-588c)4032993-8', '(DE-588a)118566512'],
#    'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#      'label': 'Österreich'}],
#    'biographicalOrHistoricalInformation': ['Politiker, Oesterreich',
#     'Bundeskanzler 1970-1983'],
#    'affiliation': [{'id': 'http://d-nb.info/gnd/2029382-3',
#      'label': 'Österreich. Bundeskanzleramt'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2016-12-16T22:40:25.000',
#     'id': 'http://d-nb.info/gnd/118566512/about'},
#    'gndIdentifier': '118566512',
#    'id': 'http://d-nb.info/gnd/118566512',
#    'preferredName': 'Kreisky, Bruno',
#    'wikipedia': [{'id': 'https://de.wikipedia.org/wiki/Bruno_Kreisky',
#      'label': 'https://de.wikipedia.org/wiki/Bruno_Kreisky'}],
#    'preferredNameEntityForThePerson': {'forename': ['Bruno'],
#     'surname': ['Kreisky']},
#    'sameAs': [{'id': 'http://viaf.org/viaf/31998484',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://id.loc.gov/authorities/n50043948',
#      'collection': {'icon': 'http://www.loc.gov/favicon.ico',
#       'name': 'NACO Authority File',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'}},
#     {'id': 'http://www.filmportal.de/person/5B113A52F8F14A879694D08C56BCEE81',
#      'collection': {'icon': 'http://filmportal.de/misc/favicon.ico',
#       'name': 'Filmportal',
#       'publisher': 'Deutsches Filminstitut',
#       'id': 'http://www.wikidata.org/entity/Q15706812',
#       'abbr': 'filmportal.de'}},
#     {'id': 'http://dbpedia.org/resource/Bruno_Kreisky',
#      'collection': {'icon': 'http://dbpedia.org/favicon.ico',
#       'name': 'DBpedia',
#       'publisher': 'DBpedia',
#       'id': 'http://www.wikidata.org/entity/QQ465',
#       'abbr': 'DBpedia'}},
#     {'id': 'http://www.wikidata.org/entity/Q44517',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'id': 'http://www.isni.org/0000000112608767',
#      'collection': {'icon': 'http://www.isni.org/sites/default/files/isni_new_favicon.ico',
#       'name': 'International Standard Name Identifier (ISNI)',
#       'publisher': 'International Standard Name Identifier (ISNI)',
#       'id': 'http://www.wikidata.org/entity/Q423048',
#       'abbr': 'ISNI'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/118566512/about'},
#     {'collection': {'name': 'Filmportal',
#       'icon': 'https://www.filmportal.de/themes/custom/filmportal/favicon.ico',
#       'publisher': 'Deutsches Filminstitut',
#       'id': 'http://www.wikidata.org/entity/Q15706812',
#       'abbr': 'filmportal.de'},
#      'id': 'http://www.filmportal.de/person/5B113A52F8F14A879694D08C56BCEE81'},
#     {'collection': {'name': 'Bibliothèque nationale de France',
#       'icon': 'http://www.bnf.fr/bnf_dev/icono/favicon.ico',
#       'publisher': 'Bibliothèque nationale de France',
#       'id': 'http://www.wikidata.org/entity/Q19938912',
#       'abbr': 'BNF'},
#      'id': 'http://catalogue.bnf.fr/ark:/12148/cb11910080j'},
#     {'collection': {'name': 'Kalliope Verbundkatalog',
#       'publisher': 'Staatsbibliothek zu Berlin - Preußischer Kulturbesitz',
#       'id': 'http://www.wikidata.org/entity/Q1722480',
#       'abbr': 'DE-611'},
#      'id': 'http://kalliope-verbund.info/gnd/118566512'},
#     {'collection': {'name': 'Wikipedia (Deutsch)',
#       'icon': 'https://de.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q48183',
#       'abbr': 'dewiki'},
#      'id': 'https://de.wikipedia.org/wiki/Bruno_Kreisky'},
#     {'collection': {'name': 'Wikipedia (English)',
#       'icon': 'https://en.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q328',
#       'abbr': 'enwiki'},
#      'id': 'https://en.wikipedia.org/wiki/Bruno_Kreisky'},
#     {'collection': {'name': 'Deutsche Digitale Bibliothek',
#       'icon': 'https://www.deutsche-digitale-bibliothek.de/favicon.ico',
#       'publisher': 'Deutsche Digitale Bibliothek',
#       'id': 'http://www.wikidata.org/entity/Q621630',
#       'abbr': 'DDB'},
#      'id': 'https://www.deutsche-digitale-bibliothek.de/entity/118566512'},
#     {'collection': {'name': 'NACO Authority File',
#       'icon': 'http://www.loc.gov/favicon.ico',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'},
#      'id': 'http://id.loc.gov/authorities/n50043948'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/31998484'},
#     {'collection': {'name': 'International Standard Name Identifier (ISNI)',
#       'icon': 'http://www.isni.org/sites/default/files/isni_new_favicon.ico',
#       'publisher': 'International Standard Name Identifier (ISNI)',
#       'id': 'http://www.wikidata.org/entity/Q423048',
#       'abbr': 'ISNI'},
#      'id': 'http://www.isni.org/0000000112608767'},
#     {'collection': {'name': 'Wikidata',
#       'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'},
#      'id': 'http://www.wikidata.org/entity/Q44517'}],
#    'depiction': [{'thumbnail': 'https://commons.wikimedia.org/wiki/Special:FilePath/Bruno%20Kreisky%201983.jpg?width=270',
#      'id': 'http://commons.wikimedia.org/wiki/Special:FilePath/Bruno%20Kreisky%201983.jpg',
#      'url': 'https://commons.wikimedia.org/wiki/File:Bruno%20Kreisky%201983.jpg?uselang=de'}]},
#   {'professionOrOccupation': [{'id': 'http://d-nb.info/gnd/4629643-8',
#      'label': 'Politologin'},
#     {'id': 'http://d-nb.info/gnd/4130076-2', 'label': 'Juristin'}],
#    'placeOfBirth': [{'id': 'http://d-nb.info/gnd/4066009-6', 'label': 'Wien'}],
#    'gender': [{'id': 'http://d-nb.info/standards/vocab/gnd/gender#notKnown',
#      'label': 'Unbekannt'}],
#    'dateOfBirth': ['1944-08-08'],
#    'variantNameEntityForThePerson': [{'forename': ['Hannelore Eva'],
#      'surname': ['Kreisky']}],
#    'familialRelationship': [{'id': 'http://d-nb.info/gnd/118566512',
#      'label': 'Kreisky, Bruno'}],
#    'type': ['Person', 'DifferentiatedPerson', 'AuthorityResource'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'gndSubjectCategory': [{'id': 'http://d-nb.info/standards/vocab/gnd/gnd-sc#7.14p',
#      'label': 'Personen zu Recht'},
#     {'id': 'http://d-nb.info/standards/vocab/gnd/gnd-sc#8.1p',
#      'label': 'Personen (Politologen, Staatstheoretiker)'}],
#    'oldAuthorityNumber': ['(DE-588a)121036073', '(DE-588c)7705035-6'],
#    'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#      'label': 'Österreich'}],
#    'biographicalOrHistoricalInformation': ['Österr. Prof. für Politikwissenschaft mit Schwerpunkt politische Theorie und Ideengeschichte'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2010-06-15T21:27:20.000',
#     'id': 'http://d-nb.info/gnd/121036073/about'},
#    'gndIdentifier': '121036073',
#    'id': 'http://d-nb.info/gnd/121036073',
#    'preferredName': 'Kreisky, Eva',
#    'wikipedia': [{'id': 'https://de.wikipedia.org/wiki/Eva_Kreisky',
#      'label': 'https://de.wikipedia.org/wiki/Eva_Kreisky'}],
#    'variantName': ['Kreisky, Hannelore Eva'],
#    'preferredNameEntityForThePerson': {'forename': ['Eva'],
#     'surname': ['Kreisky']},
#    'homepage': [{'id': 'http://evakreisky.at',
#      'label': 'http://evakreisky.at'}],
#    'sameAs': [{'id': 'http://viaf.org/viaf/9997727',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://www.wikidata.org/entity/Q1379274',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'id': 'http://www.isni.org/0000000108693073',
#      'collection': {'icon': 'http://www.isni.org/sites/default/files/isni_new_favicon.ico',
#       'name': 'International Standard Name Identifier (ISNI)',
#       'publisher': 'International Standard Name Identifier (ISNI)',
#       'id': 'http://www.wikidata.org/entity/Q423048',
#       'abbr': 'ISNI'}},
#     {'id': 'http://id.loc.gov/authorities/n80152140',
#      'collection': {'icon': 'http://www.loc.gov/favicon.ico',
#       'name': 'NACO Authority File',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/121036073/about'},
#     {'collection': {'name': 'Bibliothèque nationale de France',
#       'icon': 'http://www.bnf.fr/bnf_dev/icono/favicon.ico',
#       'publisher': 'Bibliothèque nationale de France',
#       'id': 'http://www.wikidata.org/entity/Q19938912',
#       'abbr': 'BNF'},
#      'id': 'http://catalogue.bnf.fr/ark:/12148/cb134801126'},
#     {'collection': {'name': 'Wikipedia (Deutsch)',
#       'icon': 'https://de.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q48183',
#       'abbr': 'dewiki'},
#      'id': 'https://de.wikipedia.org/wiki/Eva_Kreisky'},
#     {'collection': {'name': 'Wikipedia (English)',
#       'icon': 'https://en.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q328',
#       'abbr': 'enwiki'},
#      'id': 'https://en.wikipedia.org/wiki/Eva_Kreisky'},
#     {'collection': {'name': 'Deutsche Digitale Bibliothek',
#       'icon': 'https://www.deutsche-digitale-bibliothek.de/favicon.ico',
#       'publisher': 'Deutsche Digitale Bibliothek',
#       'id': 'http://www.wikidata.org/entity/Q621630',
#       'abbr': 'DDB'},
#      'id': 'https://www.deutsche-digitale-bibliothek.de/entity/121036073'},
#     {'collection': {'name': 'NACO Authority File',
#       'icon': 'http://www.loc.gov/favicon.ico',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'},
#      'id': 'http://id.loc.gov/authorities/n80152140'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/9997727'},
#     {'collection': {'name': 'International Standard Name Identifier (ISNI)',
#       'icon': 'http://www.isni.org/sites/default/files/isni_new_favicon.ico',
#       'publisher': 'International Standard Name Identifier (ISNI)',
#       'id': 'http://www.wikidata.org/entity/Q423048',
#       'abbr': 'ISNI'},
#      'id': 'http://www.isni.org/0000000108693073'},
#     {'collection': {'name': 'Wikidata',
#       'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'},
#      'id': 'http://www.wikidata.org/entity/Q1379274'}]},
#   {'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2016-08-11T05:45:30.000',
#     'id': 'http://d-nb.info/gnd/176237682/about'},
#    'gndIdentifier': '176237682',
#    'id': 'http://d-nb.info/gnd/176237682',
#    'preferredName': 'Kreisky, Bruno',
#    'type': ['AuthorityResource', 'Person', 'UndifferentiatedPerson'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'preferredNameEntityForThePerson': {'forename': ['Bruno'],
#     'surname': ['Kreisky']},
#    'oldAuthorityNumber': ['(DE-588a)176237682']}],
#  'aggregation': {'gndSubjectCategory.id': [{'key': 'http://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p',
#     'doc_count': 1},
#    {'key': 'http://d-nb.info/standards/vocab/gnd/gnd-sc#7.14p',
#     'doc_count': 1},
#    {'key': 'http://d-nb.info/standards/vocab/gnd/gnd-sc#8.1p',
#     'doc_count': 1}],
#   'professionOrOccupation.id': [{'key': 'http://d-nb.info/gnd/4046517-2',
#     'doc_count': 1},
#    {'key': 'http://d-nb.info/gnd/4130076-2', 'doc_count': 1},
#    {'key': 'http://d-nb.info/gnd/4629643-8', 'doc_count': 1}],
#   'geographicAreaCode.id': [{'key': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#     'doc_count': 2}],
#   'dateOfBirth': [{'key': '1911-01-22', 'doc_count': 1},
#    {'key': '1944-08-08', 'doc_count': 1}],
#   'type': [{'key': 'Person', 'doc_count': 3},
#    {'key': 'DifferentiatedPerson', 'doc_count': 2},
#    {'key': 'UndifferentiatedPerson', 'doc_count': 1}]}}

# %%
res_dict = res.json()
res_df = pd.io.json.json_normalize(res_dict['member'])

# %%
res_df[['@context', 'preferredName', 'describedBy.id', 'biographicalOrHistoricalInformation', 'dateOfBirth', 'dateOfDeath']]
# Out:
#                               @context   preferredName                        describedBy.id  \
# 0  http://lobid.org/gnd/context.jsonld  Kreisky, Bruno  http://d-nb.info/gnd/118566512/about
# 1  http://lobid.org/gnd/context.jsonld    Kreisky, Eva  http://d-nb.info/gnd/121036073/about
# 2  http://lobid.org/gnd/context.jsonld  Kreisky, Bruno  http://d-nb.info/gnd/176237682/about
#
#                                                biographicalOrHistoricalInformation   dateOfBirth  \
# 0                                [Politiker, Oesterreich, Bundeskanzler 1970-1983]  [1911-01-22]
# 1  [Österr. Prof. für Politikwissenschaft mit Schwerpunkt politische Theorie un...  [1944-08-08]
# 2                                                                              NaN           NaN
#
#     dateOfDeath
# 0  [1990-07-29]
# 1           NaN
# 2           NaN

# %%
headers = {'accept': 'application/json'}
params = {'q': 'preferredName:Graz', 'filter': 'type:TerritorialCorporateBodyOrAdministrativeUnit'}
url = 'https://lobid.org/gnd/search'
res = requests.get(url, params=params, headers=headers)

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'@context': 'https://lobid.org/gnd/context.jsonld',
#  'id': 'https://lobid.org/gnd/search?q=preferredName%3AGraz&filter=type%3ATerritorialCorporateBodyOrAdministrativeUnit',
#  'totalItems': 38,
#  'member': [{'type': ['TerritorialCorporateBodyOrAdministrativeUnit',
#     'PlaceOrGeographicName',
#     'AuthorityResource'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588b)10097697-9',
#     '(DE-588b)2028261-8',
#     '(DE-588)2028261-8',
#     '(DE-588c)4021912-4'],
#    'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'hasGeometry': [{'asWKT': ['Point ( +015.450000 +047.066666 )'],
#      'type': 'Point'}],
#    'deprecatedUri': ['http://d-nb.info/gnd/2028261-8'],
#    'biographicalOrHistoricalInformation': ['Hauptstadt der Steiermark, 1128/29 urkundl. erwähnt, 1172 Markt, 1189 Stadt'],
#    'relatedDdcWithDegreeOfDeterminacy4': [{'id': 'http://dewey.info/class/2--43655/',
#      'label': 'http://dewey.info/class/2--43655/'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2019-04-19T12:31:43.000',
#     'id': 'http://d-nb.info/gnd/040219127/about'},
#    'gndIdentifier': '4021912-4',
#    'id': 'http://d-nb.info/gnd/4021912-4',
#    'preferredName': 'Graz',
#    'wikipedia': [{'id': 'https://de.wikipedia.org/wiki/Graz',
#      'label': 'https://de.wikipedia.org/wiki/Graz'}],
#    'variantName': ['Gracia',
#     'Graecia',
#     'Graecium',
#     'Gratz',
#     'Graecii Styrorum',
#     'Grätz (Graz)',
#     'Graetz',
#     'Gradc',
#     'Gracensis',
#     'Grecium Styriae',
#     'Gräz',
#     'Graecii',
#     'Graezi',
#     'Štýrský Hradec',
#     'Stadt Graz',
#     'Grätz'],
#    'homepage': [{'id': 'http://www.graz.at', 'label': 'http://www.graz.at'}],
#    'sameAs': [{'id': 'http://viaf.org/viaf/160255975',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://d-nb.info/gnd/2028261-8',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'id': 'http://id.loc.gov/authorities/n79064653',
#      'collection': {'icon': 'http://www.loc.gov/favicon.ico',
#       'name': 'NACO Authority File',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'}},
#     {'id': 'http://www.wikidata.org/entity/Q13298',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}}]},
#   {'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'succeedingPlaceOrGeographicName': [{'id': 'http://d-nb.info/gnd/4288430-5',
#      'label': 'Graz-Waltendorf'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2019-01-25T08:21:34.000',
#     'id': 'http://d-nb.info/gnd/042903580/about'},
#    'gndIdentifier': '4290358-0',
#    'id': 'http://d-nb.info/gnd/4290358-0',
#    'preferredName': 'Waltendorf (Graz)',
#    'type': ['TerritorialCorporateBodyOrAdministrativeUnit',
#     'AuthorityResource',
#     'PlaceOrGeographicName'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4290358-0'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/233818018',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4290358-0/about'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/233818018'}]},
#   {'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'deprecatedUri': ['http://d-nb.info/gnd/408676-4'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2013-09-25T05:02:49.000',
#     'id': 'http://d-nb.info/gnd/043252117/about'},
#    'gndIdentifier': '4325211-4',
#    'id': 'http://d-nb.info/gnd/4325211-4',
#    'preferredName': 'Graz-Jakomini',
#    'type': ['AuthorityResource',
#     'TerritorialCorporateBodyOrAdministrativeUnit',
#     'PlaceOrGeographicName'],
#    'variantName': ['Graz / Bezirk (6)', 'Jakomini'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4325211-4',
#     '(DE-588b)408676-4',
#     '(DE-588)408676-4'],
#    'sameAs': [{'id': 'http://d-nb.info/gnd/408676-4',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'id': 'http://viaf.org/viaf/236518932',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4325211-4/about'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/236518932'}]},
#   {'type': ['TerritorialCorporateBodyOrAdministrativeUnit',
#     'PlaceOrGeographicName',
#     'AuthorityResource'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588b)2146671-3',
#     '(DE-588)2146671-3',
#     '(DE-588c)4093912-1'],
#    'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'hasGeometry': [{'asWKT': ['Point ( +015.400000 +047.083329 )'],
#      'type': 'Point'}],
#    'deprecatedUri': ['http://d-nb.info/gnd/2146671-3'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2017-02-10T13:30:56.000',
#     'id': 'http://d-nb.info/gnd/04093912X/about'},
#    'definition': ['Stadtbezirk von Graz, 1850 gebildet, 1906 Markt, 1938 eingemeindet'],
#    'gndIdentifier': '4093912-1',
#    'id': 'http://d-nb.info/gnd/4093912-1',
#    'preferredName': 'Graz-Eggenberg',
#    'variantName': ['Graz / Bezirk (14)', 'Eggenberg (Graz)'],
#    'hierarchicalSuperiorOfPlaceOrGeographicName': [{'id': 'http://d-nb.info/gnd/4021912-4',
#      'label': 'Graz'}],
#    'sameAs': [{'id': 'http://www.wikidata.org/entity/Q1297479',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'id': 'http://d-nb.info/gnd/2146671-3',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'id': 'http://sws.geonames.org/2780361',
#      'collection': {'icon': 'http://sws.geonames.org/favicon.ico',
#       'name': 'GeoNames',
#       'publisher': 'GeoNames',
#       'id': 'http://www.wikidata.org/entity/Q830106',
#       'abbr': 'GeoNames'}},
#     {'id': 'http://viaf.org/viaf/244562889',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4093912-1/about'},
#     {'collection': {'name': 'GeoNames',
#       'icon': 'http://www.geonames.org/geonames.ico',
#       'publisher': 'GeoNames',
#       'id': 'http://www.wikidata.org/entity/Q830106',
#       'abbr': 'geonames'},
#      'id': 'http://sws.geonames.org/2780361'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/244562889'},
#     {'collection': {'name': 'Wikidata',
#       'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'},
#      'id': 'http://www.wikidata.org/entity/Q1297479'}],
#    'depiction': [{'thumbnail': 'https://commons.wikimedia.org/wiki/Special:FilePath/Graz%20Schloss%20Eggenberg%20Seitansicht.jpg?width=270',
#      'id': 'http://commons.wikimedia.org/wiki/Special:FilePath/Graz%20Schloss%20Eggenberg%20Seitansicht.jpg',
#      'url': 'https://commons.wikimedia.org/wiki/File:Graz%20Schloss%20Eggenberg%20Seitansicht.jpg?uselang=de'}]},
#   {'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'deprecatedUri': ['http://d-nb.info/gnd/411208-8'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2013-09-25T05:03:09.000',
#     'id': 'http://d-nb.info/gnd/95099684X/about'},
#    'gndIdentifier': '4464011-0',
#    'id': 'http://d-nb.info/gnd/4464011-0',
#    'preferredName': 'Graz-Geidorf',
#    'type': ['PlaceOrGeographicName',
#     'TerritorialCorporateBodyOrAdministrativeUnit',
#     'AuthorityResource'],
#    'variantName': ['Geidorf', 'Graz / Bezirk (3)'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4464011-0',
#     '(DE-588)411208-8',
#     '(DE-588b)411208-8'],
#    'sameAs': [{'id': 'http://d-nb.info/gnd/411208-8',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'id': 'http://viaf.org/viaf/246272372',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4464011-0/about'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/246272372'}]},
#   {'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'deprecatedUri': ['http://d-nb.info/gnd/10035005-7'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2018-02-01T06:46:25.000',
#     'id': 'http://d-nb.info/gnd/949582115/about'},
#    'gndIdentifier': '4438909-7',
#    'id': 'http://d-nb.info/gnd/4438909-7',
#    'preferredName': 'Graz-Andritz',
#    'type': ['PlaceOrGeographicName',
#     'AuthorityResource',
#     'TerritorialCorporateBodyOrAdministrativeUnit'],
#    'variantName': ['Graz / Bezirk (12)', 'Andritz'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588)10035005-7',
#     '(DE-588b)10035005-7',
#     '(DE-588c)4438909-7'],
#    'sameAs': [{'id': 'http://d-nb.info/gnd/10035005-7',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'id': 'http://viaf.org/viaf/235208560',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4438909-7/about'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/235208560'}]},
#   {'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'succeedingPlaceOrGeographicName': [{'id': 'http://d-nb.info/gnd/4288429-9',
#      'label': 'Graz-Ries'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2019-01-24T08:13:34.000',
#     'id': 'http://d-nb.info/gnd/042907179/about'},
#    'gndIdentifier': '4290717-2',
#    'id': 'http://d-nb.info/gnd/4290717-2',
#    'preferredName': 'Ries (Graz)',
#    'type': ['TerritorialCorporateBodyOrAdministrativeUnit',
#     'AuthorityResource',
#     'PlaceOrGeographicName'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4290717-2'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/235617030',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4290717-2/about'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/235617030'}]},
#   {'type': ['PlaceOrGeographicName',
#     'AuthorityResource',
#     'TerritorialCorporateBodyOrAdministrativeUnit'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588)10042349-8',
#     '(DE-588b)10042349-8',
#     '(DE-588c)4438904-8'],
#    'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'deprecatedUri': ['http://d-nb.info/gnd/10042349-8'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2013-09-25T05:04:42.000',
#     'id': 'http://d-nb.info/gnd/949582077/about'},
#    'definition': ['Gleichnamige Katastralgemeinde'],
#    'gndIdentifier': '4438904-8',
#    'id': 'http://d-nb.info/gnd/4438904-8',
#    'preferredName': 'Graz-Straßgang',
#    'variantName': ['Straßgang', 'Graz / Bezirk (16)'],
#    'hierarchicalSuperiorOfPlaceOrGeographicName': [{'id': 'http://d-nb.info/gnd/4021912-4',
#      'label': 'Graz'}],
#    'sameAs': [{'id': 'http://viaf.org/viaf/247816947',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://d-nb.info/gnd/10042349-8',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4438904-8/about'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/247816947'}]},
#   {'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'deprecatedUri': ['http://d-nb.info/gnd/5012725-1'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2016-08-31T17:01:26.000',
#     'id': 'http://d-nb.info/gnd/943319161/about'},
#    'gndIdentifier': '4363079-0',
#    'id': 'http://d-nb.info/gnd/4363079-0',
#    'preferredName': 'Graz-Mariatrost',
#    'type': ['TerritorialCorporateBodyOrAdministrativeUnit',
#     'AuthorityResource',
#     'PlaceOrGeographicName'],
#    'variantName': ['Mariatrost',
#     'Graz / Bezirk (11)',
#     'Graz- Maria Trost',
#     'Maria Trost'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'hierarchicalSuperiorOfPlaceOrGeographicName': [{'id': 'http://d-nb.info/gnd/4021912-4',
#      'label': 'Graz'}],
#    'oldAuthorityNumber': ['(DE-588b)5012725-1',
#     '(DE-588c)4363079-0',
#     '(DE-588)5012725-1'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/238750135',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://d-nb.info/gnd/5012725-1',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4363079-0/about'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/238750135'}]},
#   {'precedingPlaceOrGeographicName': [{'id': 'http://d-nb.info/gnd/4382235-6',
#      'label': 'Liebenau (Graz)'}],
#    'type': ['PlaceOrGeographicName',
#     'AuthorityResource',
#     'TerritorialCorporateBodyOrAdministrativeUnit'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588b)415752-7',
#     '(DE-588c)4382234-4',
#     '(DE-588)415752-7'],
#    'geographicAreaCode': [{'id': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Steiermark'}],
#    'deprecatedUri': ['http://d-nb.info/gnd/415752-7'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2015-11-04T00:50:32.000',
#     'id': 'http://d-nb.info/gnd/945035446/about'},
#    'definition': ['Gleichnamige Katastralgemeinde'],
#    'gndIdentifier': '4382234-4',
#    'id': 'http://d-nb.info/gnd/4382234-4',
#    'preferredName': 'Graz-Liebenau',
#    'variantName': ['Graz / Bezirk (7)', 'Liebenau (Graz-Liebenau)'],
#    'hierarchicalSuperiorOfPlaceOrGeographicName': [{'id': 'http://d-nb.info/gnd/4021912-4',
#      'label': 'Graz'}],
#    'sameAs': [{'id': 'http://d-nb.info/gnd/415752-7',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'id': 'http://viaf.org/viaf/236985369',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'http://d-nb.info/gnd/4382234-4/about'},
#     {'collection': {'name': 'Virtual International Authority File (VIAF)',
#       'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'},
#      'id': 'http://viaf.org/viaf/236985369'}]}],
#  'aggregation': {'gndSubjectCategory.id': [],
#   'professionOrOccupation.id': [],
#   'geographicAreaCode.id': [{'key': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#     'doc_count': 35},
#    {'key': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#     'doc_count': 3},
#    {'key': 'http://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AAAT',
#     'doc_count': 1}],
#   'dateOfBirth': [],
#   'type': [{'key': 'PlaceOrGeographicName', 'doc_count': 38},
#    {'key': 'TerritorialCorporateBodyOrAdministrativeUnit', 'doc_count': 38},
#    {'key': 'AdministrativeUnit', 'doc_count': 2}]}}

# %%
res_dict = res.json()
res_df = pd.io.json.json_normalize(res_dict['member'])

# %%
res_df[['@context', 'preferredName', 'describedBy.id', 'biographicalOrHistoricalInformation']]
# Out:
#                               @context      preferredName                        describedBy.id  \
# 0  http://lobid.org/gnd/context.jsonld               Graz  http://d-nb.info/gnd/040219127/about
# 1  http://lobid.org/gnd/context.jsonld  Waltendorf (Graz)  http://d-nb.info/gnd/042903580/about
# 2  http://lobid.org/gnd/context.jsonld      Graz-Jakomini  http://d-nb.info/gnd/043252117/about
# 3  http://lobid.org/gnd/context.jsonld     Graz-Eggenberg  http://d-nb.info/gnd/04093912X/about
# 4  http://lobid.org/gnd/context.jsonld       Graz-Geidorf  http://d-nb.info/gnd/95099684X/about
# 5  http://lobid.org/gnd/context.jsonld       Graz-Andritz  http://d-nb.info/gnd/949582115/about
# 6  http://lobid.org/gnd/context.jsonld        Ries (Graz)  http://d-nb.info/gnd/042907179/about
# 7  http://lobid.org/gnd/context.jsonld     Graz-Straßgang  http://d-nb.info/gnd/949582077/about
# 8  http://lobid.org/gnd/context.jsonld    Graz-Mariatrost  http://d-nb.info/gnd/943319161/about
# 9  http://lobid.org/gnd/context.jsonld      Graz-Liebenau  http://d-nb.info/gnd/945035446/about
#
#                                              biographicalOrHistoricalInformation
# 0  [Hauptstadt der Steiermark, 1128/29 urkundl. erwähnt, 1172 Markt, 1189 Stadt]
# 1                                                                            NaN
# 2                                                                            NaN
# 3                                                                            NaN
# 4                                                                            NaN
# 5                                                                            NaN
# 6                                                                            NaN
# 7                                                                            NaN
# 8                                                                            NaN
# 9                                                                            NaN

# %%
res_df[['sameAs', 'preferredName']]
# Out:
#                                                                             sameAs  \
# 0  [{'id': 'http://viaf.org/viaf/160255975', 'collection': {'icon': 'http://via...
# 1  [{'id': 'http://viaf.org/viaf/233818018', 'collection': {'icon': 'http://via...
# 2  [{'id': 'http://d-nb.info/gnd/408676-4', 'collection': {'icon': 'http://www....
# 3  [{'id': 'http://www.wikidata.org/entity/Q1297479', 'collection': {'icon': 'h...
# 4  [{'id': 'http://d-nb.info/gnd/411208-8', 'collection': {'icon': 'http://www....
# 5  [{'id': 'http://d-nb.info/gnd/10035005-7', 'collection': {'icon': 'http://ww...
# 6  [{'id': 'http://viaf.org/viaf/235617030', 'collection': {'icon': 'http://via...
# 7  [{'id': 'http://viaf.org/viaf/247816947', 'collection': {'icon': 'http://via...
# 8  [{'id': 'http://viaf.org/viaf/238750135', 'collection': {'icon': 'http://via...
# 9  [{'id': 'http://d-nb.info/gnd/415752-7', 'collection': {'icon': 'http://www....
#
#        preferredName
# 0               Graz
# 1  Waltendorf (Graz)
# 2      Graz-Jakomini
# 3     Graz-Eggenberg
# 4       Graz-Geidorf
# 5       Graz-Andritz
# 6        Ries (Graz)
# 7     Graz-Straßgang
# 8    Graz-Mariatrost
# 9      Graz-Liebenau

# %%
from SPARQLWrapper import SPARQLWrapper, POST, BASIC

# %%
sparql = SPARQLWrapper("https://triplestore.acdh-dev.oeaw.ac.at/summer2020/sparql")

sparql.setHTTPAuth(BASIC)
sparql.setCredentials("", "")
sparql.setMethod(POST)

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX frbroo: <http://iflastandards.info/ns/fr/frbr/frbroo#>
PREFIX bds: <http://www.bigdata.com/rdf/search#>
SELECT ?name ?sub ?prof_val WHERE {
  # ?sub a crm:E21_Person ;
		rdfs:label ?name ;
  	    crm:P14i_performed ?prof .
  # ?prof rdf:value ?prof_val .
  FILTER CONTAINS(str(?prof), "Architekt")
}

LIMIT 100
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df
# Out:
#    prof_val.type                                                           prof_val.value  \
# 0        literal                Bildende und angewandte Kunst >> Baumeister und Architekt
# 1        literal                 Bildende und angewandte Kunst >> Architekt und Steinmetz
# 2        literal            Bildende und angewandte Kunst >> Architekt und Kunstgewerbler
# 3        literal  Bildende und angewandte Kunst >> Architekt, Kunstgewerbler und Designer
# 4        literal        Bildende und angewandte Kunst >> Architekt und Fachschriftsteller
# ..           ...                                                                      ...
# 95       literal                               Bildende und angewandte Kunst >> Architekt
# 96       literal                               Bildende und angewandte Kunst >> Architekt
# 97       literal                               Bildende und angewandte Kunst >> Architekt
# 98       literal                               Bildende und angewandte Kunst >> Architekt
# 99       literal                               Bildende und angewandte Kunst >> Architekt
#
#    sub.type                             sub.value name.xml:lang name.type  \
# 0       uri  http://127.0.0.1:8001/entity/103135/            de   literal
# 1       uri  http://127.0.0.1:8001/entity/103647/            de   literal
# 2       uri  http://127.0.0.1:8001/entity/109183/            de   literal
# 3       uri  http://127.0.0.1:8001/entity/114397/            de   literal
# 4       uri   http://127.0.0.1:8001/entity/27139/            de   literal
# ..      ...                                   ...           ...       ...
# 95      uri   http://127.0.0.1:8001/entity/68308/            de   literal
# 96      uri   http://127.0.0.1:8001/entity/70018/            de   literal
# 97      uri   http://127.0.0.1:8001/entity/70156/            de   literal
# 98      uri   http://127.0.0.1:8001/entity/71378/            de   literal
# 99      uri   http://127.0.0.1:8001/entity/72104/            de   literal
#
#                               name.value
# 0             Person known as Franz Beer
# 1   Person known as Johan Ludwig Kranner
# 2            Person known as Franz Seeck
# 3           Person known as Joseph Urban
# 4      Person known as Heinrich Tessenow
# ..                                   ...
# 95       Person known as Gustav Korompay
# 96         Person known as Karl Koechlin
# 97            Person known as Karl König
# 98       Person known as August Kirstein
# 99         Person known as Alfred Keller
#
# [100 rows x 7 columns]

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX frbroo: <http://iflastandards.info/ns/fr/frbr/frbroo#>
PREFIX bds: <http://www.bigdata.com/rdf/search#>
SELECT ?name ?sub ?prof_val ?rank WHERE {
  # ?sub a crm:E21_Person ;
		rdfs:label ?name ;
  	    crm:P14i_performed ?prof .
  # ?prof rdf:value ?prof_val .
  # ?prof_val bds:search "Architekt" .
  # ?prof_val bds:rank ?rank .
}

LIMIT 100

""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df
# Out:
#    prof_val.type                                                           prof_val.value  \
# 0        literal                Bildende und angewandte Kunst >> Baumeister und Architekt
# 1        literal                 Bildende und angewandte Kunst >> Architekt und Steinmetz
# 2        literal            Bildende und angewandte Kunst >> Architekt und Kunstgewerbler
# 3        literal  Bildende und angewandte Kunst >> Architekt, Kunstgewerbler und Designer
# 4        literal        Bildende und angewandte Kunst >> Architekt und Fachschriftsteller
# ..           ...                                                                      ...
# 95       literal                               Bildende und angewandte Kunst >> Architekt
# 96       literal                               Bildende und angewandte Kunst >> Architekt
# 97       literal                               Bildende und angewandte Kunst >> Architekt
# 98       literal                               Bildende und angewandte Kunst >> Architekt
# 99       literal                               Bildende und angewandte Kunst >> Architekt
#
#                            rank.datatype rank.type rank.value sub.type  \
# 0   http://www.w3.org/2001/XMLSchema#int   literal         21      uri
# 1   http://www.w3.org/2001/XMLSchema#int   literal         14      uri
# 2   http://www.w3.org/2001/XMLSchema#int   literal         12      uri
# 3   http://www.w3.org/2001/XMLSchema#int   literal         17      uri
# 4   http://www.w3.org/2001/XMLSchema#int   literal         11      uri
# ..                                   ...       ...        ...      ...
# 95  http://www.w3.org/2001/XMLSchema#int   literal          3      uri
# 96  http://www.w3.org/2001/XMLSchema#int   literal          3      uri
# 97  http://www.w3.org/2001/XMLSchema#int   literal          3      uri
# 98  http://www.w3.org/2001/XMLSchema#int   literal          3      uri
# 99  http://www.w3.org/2001/XMLSchema#int   literal          3      uri
#
#                                sub.value name.xml:lang name.type  \
# 0   http://127.0.0.1:8001/entity/103135/            de   literal
# 1   http://127.0.0.1:8001/entity/103647/            de   literal
# 2   http://127.0.0.1:8001/entity/109183/            de   literal
# 3   http://127.0.0.1:8001/entity/114397/            de   literal
# 4    http://127.0.0.1:8001/entity/27139/            de   literal
# ..                                   ...           ...       ...
# 95   http://127.0.0.1:8001/entity/68308/            de   literal
# 96   http://127.0.0.1:8001/entity/70018/            de   literal
# 97   http://127.0.0.1:8001/entity/70156/            de   literal
# 98   http://127.0.0.1:8001/entity/71378/            de   literal
# 99   http://127.0.0.1:8001/entity/72104/            de   literal
#
#                               name.value
# 0             Person known as Franz Beer
# 1   Person known as Johan Ludwig Kranner
# 2            Person known as Franz Seeck
# 3           Person known as Joseph Urban
# 4      Person known as Heinrich Tessenow
# ..                                   ...
# 95       Person known as Gustav Korompay
# 96         Person known as Karl Koechlin
# 97            Person known as Karl König
# 98       Person known as August Kirstein
# 99         Person known as Alfred Keller
#
# [100 rows x 10 columns]

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX frbroo: <http://iflastandards.info/ns/fr/frbr/frbroo#>
PREFIX bds: <http://www.bigdata.com/rdf/search#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT ?name ?sub ?prof_val ?uri WHERE {
  # ?sub a crm:E21_Person ;
		rdfs:label ?name ;
  	    crm:P14i_performed ?prof .
   OPTIONAL {?sub owl:sameAs ?uri} .
  # ?prof rdf:value ?prof_val .
  FILTER CONTAINS(str(?prof), "Architekt")
}

LIMIT 100

""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df
# Out:
#    sub.type                            sub.value prof_val.type  \
# 0       uri  http://127.0.0.1:8001/entity/92206/       literal
# 1       uri  http://127.0.0.1:8001/entity/92211/       literal
# 2       uri  http://127.0.0.1:8001/entity/92220/       literal
# 3       uri  http://127.0.0.1:8001/entity/92264/       literal
# 4       uri  http://127.0.0.1:8001/entity/92690/       literal
# ..      ...                                  ...           ...
# 95      uri  http://127.0.0.1:8001/entity/84026/       literal
# 96      uri  http://127.0.0.1:8001/entity/84110/       literal
# 97      uri  http://127.0.0.1:8001/entity/84113/       literal
# 98      uri  http://127.0.0.1:8001/entity/86069/       literal
# 99      uri  http://127.0.0.1:8001/entity/86256/       literal
#
#                                 prof_val.value name.xml:lang name.type  \
# 0   Bildende und angewandte Kunst >> Architekt            de   literal
# 1   Bildende und angewandte Kunst >> Architekt            de   literal
# 2   Bildende und angewandte Kunst >> Architekt            de   literal
# 3   Bildende und angewandte Kunst >> Architekt            de   literal
# 4   Bildende und angewandte Kunst >> Architekt            de   literal
# ..                                         ...           ...       ...
# 95  Bildende und angewandte Kunst >> Architekt            de   literal
# 96  Bildende und angewandte Kunst >> Architekt            de   literal
# 97  Bildende und angewandte Kunst >> Architekt            de   literal
# 98  Bildende und angewandte Kunst >> Architekt            de   literal
# 99  Bildende und angewandte Kunst >> Architekt            de   literal
#
#                                         name.value uri.type                         uri.value
# 0    Person known as Theophil  Freiherr von Hansen      uri   https://d-nb.info/gnd/118545760
# 1      Person known as Carl Freiherr von Hasenauer      uri   https://d-nb.info/gnd/118546597
# 2                   Person known as Hermann Helmer      uri   https://d-nb.info/gnd/118710230
# 3   Person known as Ferdinand Ritter von Kirschner      uri  https://d-nb.info/gnd/1013623398
# 4            Person known as Ferdinand II. Fellner      uri   https://d-nb.info/gnd/118686623
# ..                                             ...      ...                               ...
# 95           Person known as Michael Ignaz Fellner      uri   https://d-nb.info/gnd/144008378
# 96       Person known as Heinrich Frh. von Ferstel      uri   https://d-nb.info/gnd/118532634
# 97            Person known as Max Frh. von Ferstel      uri   https://d-nb.info/gnd/135963540
# 98                Person known as Julius Deininger      uri   https://d-nb.info/gnd/130137189
# 99                     Person known as Rudolf Dick      uri   https://d-nb.info/gnd/143951009
#
# [100 rows x 9 columns]

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX frbroo: <http://iflastandards.info/ns/fr/frbr/frbroo#>
PREFIX bds: <http://www.bigdata.com/rdf/search#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX wdtn: <http://www.wikidata.org/prop/direct-normalized/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>

SELECT ?name ?sub ?prof_val ?uri ?wikidata ?citizenship_label WHERE {
  # ?sub a crm:E21_Person ;
		rdfs:label ?name ;
  	    crm:P14i_performed ?prof .
   OPTIONAL {?sub owl:sameAs ?uri .
    FILTER CONTAINS(str(?uri), "d-nb.info") .
    SERVICE <https://query.wikidata.org/sparql> { 
    	# ?wikidata wdtn:P227 ?uri .
      OPTIONAL {?wikidata wdt:P27 ?citizenship .
      			# ?citizenship rdfs:label ?citizenship_label
      FILTER(lang(?citizenship_label) = 'de' || lang(?citizenship_label) = 'en')
      }
    }
  } .
  # ?prof rdf:value ?prof_val .
  FILTER CONTAINS(str(?prof), "Architekt")
}

LIMIT 100

""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df
# Out:
#    sub.type                            sub.value uri.type                        uri.value  \
# 0       uri  http://127.0.0.1:8001/entity/92206/      uri  https://d-nb.info/gnd/118545760
# 1       uri  http://127.0.0.1:8001/entity/92206/      uri  https://d-nb.info/gnd/118545760
# 2       uri  http://127.0.0.1:8001/entity/92211/      uri  https://d-nb.info/gnd/118546597
# 3       uri  http://127.0.0.1:8001/entity/92211/      uri  https://d-nb.info/gnd/118546597
# 4       uri  http://127.0.0.1:8001/entity/92220/      uri  https://d-nb.info/gnd/118710230
# ..      ...                                  ...      ...                              ...
# 95      uri  http://127.0.0.1:8001/entity/65111/      NaN                              NaN
# 96      uri  http://127.0.0.1:8001/entity/67741/      NaN                              NaN
# 97      uri  http://127.0.0.1:8001/entity/67842/      uri  https://d-nb.info/gnd/136441459
# 98      uri  http://127.0.0.1:8001/entity/67842/      uri  https://d-nb.info/gnd/136441459
# 99      uri  http://127.0.0.1:8001/entity/67842/      uri  https://d-nb.info/gnd/136441459
#
#    citizenship_label.xml:lang citizenship_label.type citizenship_label.value wikidata.type  \
# 0                          en                literal                 Austria           uri
# 1                          de                literal              Österreich           uri
# 2                          en                literal                 Austria           uri
# 3                          de                literal              Österreich           uri
# 4                          de                literal             Deutschland           uri
# ..                        ...                    ...                     ...           ...
# 95                        NaN                    NaN                     NaN           NaN
# 96                        NaN                    NaN                     NaN           NaN
# 97                         en                literal                 Austria           uri
# 98                         de                literal              Österreich           uri
# 99                         de                literal       Österreich-Ungarn           uri
#
#                              wikidata.value prof_val.type  \
# 0     http://www.wikidata.org/entity/Q78638       literal
# 1     http://www.wikidata.org/entity/Q78638       literal
# 2     http://www.wikidata.org/entity/Q84541       literal
# 3     http://www.wikidata.org/entity/Q84541       literal
# 4     http://www.wikidata.org/entity/Q65847       literal
# ..                                      ...           ...
# 95                                      NaN       literal
# 96                                      NaN       literal
# 97  http://www.wikidata.org/entity/Q1449935       literal
# 98  http://www.wikidata.org/entity/Q1449935       literal
# 99  http://www.wikidata.org/entity/Q1449935       literal
#
#                                 prof_val.value name.xml:lang name.type  \
# 0   Bildende und angewandte Kunst >> Architekt            de   literal
# 1   Bildende und angewandte Kunst >> Architekt            de   literal
# 2   Bildende und angewandte Kunst >> Architekt            de   literal
# 3   Bildende und angewandte Kunst >> Architekt            de   literal
# 4   Bildende und angewandte Kunst >> Architekt            de   literal
# ..                                         ...           ...       ...
# 95  Bildende und angewandte Kunst >> Architekt            de   literal
# 96  Bildende und angewandte Kunst >> Architekt            de   literal
# 97  Bildende und angewandte Kunst >> Architekt            de   literal
# 98  Bildende und angewandte Kunst >> Architekt            de   literal
# 99  Bildende und angewandte Kunst >> Architekt            de   literal
#
#                                        name.value
# 0   Person known as Theophil  Freiherr von Hansen
# 1   Person known as Theophil  Freiherr von Hansen
# 2     Person known as Carl Freiherr von Hasenauer
# 3     Person known as Carl Freiherr von Hasenauer
# 4                  Person known as Hermann Helmer
# ..                                            ...
# 95                     Person known as Paul Lange
# 96               Person known as František Krásný
# 97           Person known as Franz Frh. von Krauß
# 98           Person known as Franz Frh. von Krauß
# 99           Person known as Franz Frh. von Krauß
#
# [100 rows x 14 columns]

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX frbroo: <http://iflastandards.info/ns/fr/frbr/frbroo#>
PREFIX bds: <http://www.bigdata.com/rdf/search#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX wdtn: <http://www.wikidata.org/prop/direct-normalized/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>

SELECT ?citizenship (COUNT(?citizenship) as ?count) ?citizenship_label WHERE {
  # ?sub a crm:E21_Person ;
		rdfs:label ?name ;
  	    crm:P14i_performed ?prof .
   OPTIONAL {?sub owl:sameAs ?uri .
    FILTER CONTAINS(str(?uri), "d-nb.info") .
    SERVICE <https://query.wikidata.org/sparql> { 
    	# ?wikidata wdtn:P227 ?uri .
      OPTIONAL {?wikidata wdt:P27 ?citizenship .
      			# ?citizenship rdfs:label ?citizenship_label
      FILTER(lang(?citizenship_label) = 'de' || lang(?citizenship_label) = 'en')
      }
    }
  } .
  # ?prof rdf:value ?prof_val .
  FILTER CONTAINS(str(?prof), "Architekt")
} GROUP BY ?citizenship ?citizenship_label 

LIMIT 100

""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df
# Out:
#    citizenship.type                       citizenship.value citizenship_label.xml:lang  \
# 0               uri      http://www.wikidata.org/entity/Q40                         en
# 1               uri      http://www.wikidata.org/entity/Q40                         de
# 2               uri     http://www.wikidata.org/entity/Q183                         de
# 3               uri     http://www.wikidata.org/entity/Q183                         en
# 4               uri   http://www.wikidata.org/entity/Q28513                         de
# 5               uri   http://www.wikidata.org/entity/Q28513                         en
# 6               NaN                                     NaN                        NaN
# 7               uri  http://www.wikidata.org/entity/Q131964                         en
# 8               uri  http://www.wikidata.org/entity/Q131964                         de
# 9               uri  http://www.wikidata.org/entity/Q533534                         de
# 10              uri  http://www.wikidata.org/entity/Q533534                         en
# 11              uri      http://www.wikidata.org/entity/Q30                         de
# 12              uri      http://www.wikidata.org/entity/Q30                         en
#
#    citizenship_label.type   citizenship_label.value                            count.datatype  \
# 0                 literal                   Austria  http://www.w3.org/2001/XMLSchema#integer
# 1                 literal                Österreich  http://www.w3.org/2001/XMLSchema#integer
# 2                 literal               Deutschland  http://www.w3.org/2001/XMLSchema#integer
# 3                 literal                   Germany  http://www.w3.org/2001/XMLSchema#integer
# 4                 literal         Österreich-Ungarn  http://www.w3.org/2001/XMLSchema#integer
# 5                 literal           Austria-Hungary  http://www.w3.org/2001/XMLSchema#integer
# 6                     NaN                       NaN  http://www.w3.org/2001/XMLSchema#integer
# 7                 literal           Austrian Empire  http://www.w3.org/2001/XMLSchema#integer
# 8                 literal      Kaisertum Österreich  http://www.w3.org/2001/XMLSchema#integer
# 9                 literal             Cisleithanien  http://www.w3.org/2001/XMLSchema#integer
# 10                literal              Cisleithania  http://www.w3.org/2001/XMLSchema#integer
# 11                literal        Vereinigte Staaten  http://www.w3.org/2001/XMLSchema#integer
# 12                literal  United States of America  http://www.w3.org/2001/XMLSchema#integer
#
#    count.type count.value
# 0     literal          30
# 1     literal          30
# 2     literal           9
# 3     literal           9
# 4     literal          13
# 5     literal          13
# 6     literal           0
# 7     literal           8
# 8     literal           8
# 9     literal           1
# 10    literal           1
# 11    literal           1
# 12    literal           1

# %% [markdown]
# # Exercise
# * Use either SPARQL or Rest to enrich the data
# * You can use either Colab or head to https://summer2020.acdh-dev.oeaw.ac.at/login
# * Try to enrich the painters ("Maler" in German) of the ÖBL dataset with data from external reference resources:
#     - eg. filter for painters in the dataset and use federated queries to retrieve awards they received from Wikidata (Sparql)
